# %% [markdown]
# 1. 중첩 for을 이용하여 구구단을 2단부터 9단까지 출력하는 프로그램을 작성하세요.

# %%
for dan in range(2,10):
    print('-----------')
    for i in range(1,10):
        print(dan,'x', i, '=' , dan*i)
# Out:
# -----------
# 2 x 1 = 2
# 2 x 2 = 4
# 2 x 3 = 6
# 2 x 4 = 8
# 2 x 5 = 10
# 2 x 6 = 12
# 2 x 7 = 14
# 2 x 8 = 16
# 2 x 9 = 18
# -----------
# 3 x 1 = 3
# 3 x 2 = 6
# 3 x 3 = 9
# 3 x 4 = 12
# 3 x 5 = 15
# 3 x 6 = 18
# 3 x 7 = 21
# 3 x 8 = 24
# 3 x 9 = 27
# -----------
# 4 x 1 = 4
# 4 x 2 = 8
# 4 x 3 = 12
# 4 x 4 = 16
# 4 x 5 = 20
# 4 x 6 = 24
# 4 x 7 = 28
# 4 x 8 = 32
# 4 x 9 = 36
# -----------
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# -----------
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# -----------
# 7 x 1 = 7
# 7 x 2 = 14
# 7 x 3 = 21
# 7 x 4 = 28
# 7 x 5 = 35
# 7 x 6 = 42
# 7 x 7 = 49
# 7 x 8 = 56
# 7 x 9 = 63
# -----------
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# -----------
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# ...

# %% [markdown]
# 2. for문을 이용하여 왼쪽과 같이 숫자자리 중에 3이나 6이나 9가 있으면 그 개수만큼 'clap' 을 출력하는 '369' 게임을 작성하세요.

# %%
print('3, 6, 9 게임을 해보자! ')
print('-----------------------')

for i in range(1,10):
    cnt=0
    for n in str(i):
            if int(n)%3==0 and int(n)!= 0:
                cnt=cnt+1
            
    if cnt!=0:
            print('👏' * cnt, '(', i, ')')
    if cnt ==0:
            print(i)
# Out:
# 3, 6, 9 게임을 해보자!
# -----------------------
# 1
# 2
# 👏 ( 3 )
# 4
# 5
# 👏 ( 6 )
# 7
# 8
# 👏 ( 9 )

# %%
#3.6.9 게임의 범위를 정하자. 
for i in range(1,334):
    cnt=0
    for n in str(i):                 #n이라는 변수에 i 의 값을 할당해주자. 
        if int(n)%3==0 and int(n)!=0: # n의 값이 3으로 나누워 나머지가 0일때이고, n이 0이 아닐때 ->  예를들어, 1 나누기 3의 나머지는 0이 아님으로
                                       # and 조건에 성립하지 않음으로 밑으로 내려간다. 
                                       
            
            cnt=cnt+1                  # 위의 조건을 충족하면, cnt 넘버를 +1 하자. 
                    
        if cnt!=0:                      # 만약에, cnt 가 0이 아닐때 (ex: 3/3 => 0 -> 0이)는 3이 들어가므로, if 문 실행을 하여 clap을 프린트
            print(i, 'clap' * cnt, )                # 만약에 cnt가 0이면, (ex: 5/3=>2)으로 for을 충족하지 않음, 그대로 프린트 
        if cnt==0:
            print(i)
# Out:
# 1
# 2
# 3 clap
# 4
# 5
# 6 clap
# 7
# 8
# 9 clap
# 10
# 10
# 11
# 11
# 12
# 12
# 13
# 13 clap
# 14
# 14
# 15
# 15
# 16
# 16 clap
# 17
# 17
# 18
# 18
# 19
# 19 clap
# 20
# 20
# 21
# 21
# 22
# 22
# 23
# 23 clap
# 24
# 24
# 25
# 25
# 26
# 26 clap
# 27
# 27
# 28
# 28
# 29
# 29 clap
# 30 clap
# 30 clap
# 31 clap
# 31 clap
# 32 clap
# 32 clap
# 33 clap
# 33 clapclap
# 34 clap
# 34 clap
# 35 clap
# 35 clap
# 36 clap
# 36 clapclap
# 37 clap
# 37 clap
# 38 clap
# 38 clap
# 39 clap
# 39 clapclap
# 40
# 40
# 41
# 41
# 42
# 42
# 43
# 43 clap
# 44
# 44
# 45
# 45
# 46
# 46 clap
# 47
# 47
# 48
# 48
# 49
# 49 clap
# 50
# 50
# 51
# 51
# 52
# 52
# 53
# 53 clap
# 54
# 54
# 55
# 55
# 56
# 56 clap
# 57
# 57
# 58
# 58
# 59
# 59 clap
# 60 clap
# 60 clap
# 61 clap
# 61 clap
# 62 clap
# 62 clap
# 63 clap
# 63 clapclap
# 64 clap
# 64 clap
# 65 clap
# 65 clap
# 66 clap
# 66 clapclap
# 67 clap
# 67 clap
# 68 clap
# 68 clap
# 69 clap
# 69 clapclap
# 70
# 70
# 71
# 71
# 72
# 72
# 73
# 73 clap
# 74
# 74
# 75
# 75
# ...

# %%
for i in range(1,15):
    i = str(i)
    for n in i:
        print(n)
        if n%3==0 and n!=0:
            cnt=cnt+1
    if cnt!=0:
        print ('clap')
    if cnt==0:
        print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 1
# 0
# 1
# 1
# 1
# 2
# 1
# 3
# 1
# 4

# %%
1,
